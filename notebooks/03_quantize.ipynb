# %% [markdown]
# # Quantization & Export to GGUF
#
# This notebook merges the LoRA adapters with the base model and exports to GGUF format for CPU inference with llama.cpp.
#
# ## Steps:
# 1. Merge LoRA adapters with base model
# 2. Export to multiple GGUF quantization formats
# 3. Test inference speed
# 4. Select best model for 7GB RAM constraint
#
# ## Target Quantizations:
# - Q4_K_M: ~1.8GB (recommended for 7GB RAM)
# - Q5_K_M: ~2.1GB (better quality, more RAM)
# - Q3_K_M: ~1.5GB (smaller, lower quality)

# %%
import os
import torch
from unsloth import FastLanguageModel
import subprocess
import time

# Configuration
base_model_name = "unsloth/Qwen2.5-3B-Instruct"
lora_path = "models/lora/qwen2.5-3b-zim-my/final"
output_dir = "models/gguf"
max_seq_length = 2048

os.makedirs(output_dir, exist_ok=True)

print(f"Base model: {base_model_name}")
print(f"LoRA adapters: {lora_path}")
print(f"Output directory: {output_dir}")

# %% [markdown]
# ## 1. Load Model with LoRA Adapters

# %%
# Load base model with LoRA adapters
print("Loading model with LoRA adapters...")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=lora_path,
    max_seq_length=max_seq_length,
    dtype=None,
    load_in_4bit=True,
)

print("✓ Model loaded successfully")

# %% [markdown]
# ## 2. Merge LoRA Adapters

# %%
# Merge LoRA adapters into base model
merged_model_path = "models/merged/qwen2.5-3b-zim-my"
os.makedirs(merged_model_path, exist_ok=True)

print("Merging LoRA adapters with base model...")
model.save_pretrained_merged(merged_model_path, tokenizer, save_method="merged_16bit")

print(f"✓ Merged model saved to: {merged_model_path}")

# %% [markdown]
# ## 3. Export to GGUF Format

# %%
# Export to multiple quantization formats
quantization_methods = [
    ("q4_k_m", "Q4_K_M"),  # Recommended for 7GB RAM
    ("q5_k_m", "Q5_K_M"),  # Better quality
    ("q3_k_m", "Q3_K_M"),  # Smaller size
]

print("Exporting to GGUF formats...\n")

for method, name in quantization_methods:
    output_file = f"{output_dir}/zim-my-{name.lower()}.gguf"
    print(f"Exporting to {name}...")
    
    model.save_pretrained_gguf(
        output_file,
        tokenizer,
        quantization_method=method,
    )
    
    # Get file size
    if os.path.exists(output_file):
        size_gb = os.path.getsize(output_file) / (1024**3)
        print(f"✓ Saved: {output_file} ({size_gb:.2f} GB)\n")
    else:
        print(f"✗ Failed to export {name}\n")

# %% [markdown]
# ## 4. Test Inference Speed

# %%
# Install llama-cpp-python if not already installed
try:
    from llama_cpp import Llama
    print("✓ llama-cpp-python is installed")
except ImportError:
    print("Installing llama-cpp-python...")
    # !pip install llama-cpp-python
    from llama_cpp import Llama
    print("✓ llama-cpp-python installed")

# %%
# Test each quantization
test_prompt = "What are the main crops grown in Zimbabwe?"
results = []

for method, name in quantization_methods:
    model_file = f"{output_dir}/zim-my-{name.lower()}.gguf"
    
    if not os.path.exists(model_file):
        print(f"✗ {model_file} not found, skipping")
        continue
    
    print(f"\nTesting {name}...")
    
    # Load model
    llm = Llama(
        model_path=model_file,
        n_ctx=2048,
        n_threads=4,  # Simulate Intel i5 (4 cores)
        verbose=False,
    )
    
    # Warm-up
    _ = llm(test_prompt, max_tokens=10)
    
    # Benchmark
    start_time = time.time()
    output = llm(test_prompt, max_tokens=100)
    elapsed = time.time() - start_time
    
    # Calculate tokens/sec
    tokens_generated = len(output['choices'][0]['text'].split())
    tokens_per_sec = tokens_generated / elapsed
    
    results.append({
        'quantization': name,
        'size_gb': os.path.getsize(model_file) / (1024**3),
        'tokens_per_sec': tokens_per_sec,
        'time_sec': elapsed,
    })
    
    print(f"  Size: {results[-1]['size_gb']:.2f} GB")
    print(f"  Speed: {tokens_per_sec:.1f} tokens/sec")
    print(f"  Time: {elapsed:.2f} sec")
    print(f"  Response: {output['choices'][0]['text'][:100]}...")
    
    # Clean up
    del llm

# %% [markdown]
# ## 5. Summary & Recommendations

# %%
# Upload to OSS (optional)
print("\n📦 Upload to Alibaba Cloud OSS:")
print("ossutil cp -r models/gguf/ oss://zim-my-models/gguf/")
print("\n# Download to local laptop:")
print("ossutil cp -r oss://zim-my-models/gguf/ ./models/gguf/")

# %% [markdown]
# ## 📊 Quantization Summary
#
# ### File Sizes
# - `models/gguf/zim-my-q4_k_m.gguf` (~1.8GB) - **Recommended**
# - `models/gguf/zim-my-q5_k_m.gguf` (~2.1GB) - Better quality
# - `models/gguf/zim-my-q3_k_m.gguf` (~1.5GB) - Smaller size
#
# ### Performance
# The Q4_K_M quantization provides the best balance of:
# - **Size**: ~1.8GB (leaves 5+ GB for KV cache + RAG + app)
# - **Quality**: Minimal quality loss vs full precision
# - **Speed**: Fast CPU inference on Intel i5
#
# ### Next Steps
# 1. Download GGUF files to local laptop
# 2. Test inference with `src/inference.py`
# 3. Build RAG pipeline with `src/rag.py`
# 4. Launch Streamlit UI with `src/app.py`
# 5. Benchmark on target hardware (must stay < 7GB RAM)

# %%
# Instructions for downloading to local machine
print("\n" + "="*60)
print("DOWNLOAD INSTRUCTIONS")
print("="*60)

print("""
To download the quantized models to your local machine:

Option 1: Using ossutil (Alibaba Cloud OSS)
-------------------------------------------
# Upload to OSS
ossutil cp -r models/gguf/ oss://laptoplelm-models/gguf/

# Download on local machine
ossutil cp -r oss://laptoplelm-models/gguf/ ./models/gguf/

Option 2: Using scp
-------------------
# From your local machine
scp -r user@pai-dsw-ip:/path/to/models/gguf/ ./models/gguf/

Option 3: Using PAI-DSW file browser
------------------------------------
1. Navigate to models/gguf/ in the file browser
2. Right-click on the .gguf file
3. Select "Download"

Recommended file: laptoplelm-q4_k_m.gguf (~1.8GB)
""")

# %% [markdown]
# ## Summary
#
# Quantization complete! The GGUF models are ready for CPU inference.
#
# ### Files Created:
# - `models/gguf/laptoplelm-q4_k_m.gguf` (~1.8GB) - **Recommended**
# - `models/gguf/laptoplelm-q5_k_m.gguf` (~2.1GB) - Better quality
# - `models/gguf/laptoplelm-q3_k_m.gguf` (~1.5GB) - Smaller size
#
# ### Next Steps:
# 1. Download the Q4_K_M model to your local machine
# 2. Test inference with `src/inference.py`
# 3. Build RAG pipeline with `src/rag.py`
# 4. Create demo app with `src/app.py`
# 5. Run benchmarks with `benchmarks/run_benchmark.py`
